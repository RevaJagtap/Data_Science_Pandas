# %% [markdown]
# ### Groupby using Pandas

# %% [markdown]
# Groupby is a pretty simple concept. We can create a grouping of categories and apply a function to the categories. It’s a simple concept but it’s an extremely valuable technique that’s widely used in data science. In real data science projects, you’ll be dealing with large amounts of data and trying things over and over, so for efficiency, we use Groupby concept. Groupby concept is really important because it’s ability to aggregate data efficiently, both in performance and the amount code is magnificent.

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\YugandharJagtap\Desktop\DATA SCIENTIST\DataScience\Pandas\DataFrame\DataFrame sir files\matches.csv')
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
# If we want first five records
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# check number of records
df.shape
# Out:
# (756, 18)

# %%
#check the size
df.size
# Out:
# 13608

# %%
# check unique seasons
df.Season.unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
# sort the data according to Season
df.sort_values(by='Season',inplace=True)

# %%
# check unique seasons after sort
df.Season.unique()
# Out:
# array(['IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011', 'IPL-2012',
#        'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016', 'IPL-2017',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
# Groupby is applicable on Category first
# so check data type of each column
df.dtypes
# Out:
# id                  int64
# Season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %% [markdown]
# # syntax: df.groupby(columnName)

# %%
# Seasonwise groupby
df.groupby('Season')

# %%
# to see the output we need typecasting
list(df.groupby('Season'))
# when we apply a groupby it gives 2 things
# key: an individual category from that column means IPL -2010 IPL-2013 etc
# data: dataframe associated with above key
# Out:
# [('IPL-2008',
#         id    Season        city        date                        team1  \
#   116  117  IPL-2008      Mumbai  01-06-2008          Chennai Super Kings
#   82    83  IPL-2008      Jaipur  04-05-2008          Chennai Super Kings
#   81    82  IPL-2008      Mumbai  04-05-2008               Mumbai Indians
#   80    81  IPL-2008  Chandigarh  03-05-2008              Kings XI Punjab
#   79    80  IPL-2008   Hyderabad  25-05-2008              Deccan Chargers
#   78    79  IPL-2008     Chennai  02-05-2008          Chennai Super Kings
#   77    78  IPL-2008      Jaipur  01-05-2008             Rajasthan Royals
#   76    77  IPL-2008   Hyderabad  01-05-2008              Deccan Chargers
#   75    76  IPL-2008       Delhi  30-04-2008             Delhi Daredevils
#   74    75  IPL-2008     Kolkata  29-04-2008        Kolkata Knight Riders
#   73    74  IPL-2008   Bangalore  28-04-2008          Chennai Super Kings
# ...

# %%
list(df.groupby('Season'))[0]
# it include Season and Data of that perticular Season
# Out:
# ('IPL-2008',
#        id    Season        city        date                        team1  \
#  116  117  IPL-2008      Mumbai  01-06-2008          Chennai Super Kings
#  82    83  IPL-2008      Jaipur  04-05-2008          Chennai Super Kings
#  81    82  IPL-2008      Mumbai  04-05-2008               Mumbai Indians
#  80    81  IPL-2008  Chandigarh  03-05-2008              Kings XI Punjab
#  79    80  IPL-2008   Hyderabad  25-05-2008              Deccan Chargers
#  78    79  IPL-2008     Chennai  02-05-2008          Chennai Super Kings
#  77    78  IPL-2008      Jaipur  01-05-2008             Rajasthan Royals
#  76    77  IPL-2008   Hyderabad  01-05-2008              Deccan Chargers
#  75    76  IPL-2008       Delhi  30-04-2008             Delhi Daredevils
#  74    75  IPL-2008     Kolkata  29-04-2008        Kolkata Knight Riders
#  73    74  IPL-2008   Bangalore  28-04-2008          Chennai Super Kings
#  72    73  IPL-2008  Chandigarh  27-04-2008             Delhi Daredevils
# ...

# %%
list(df.groupby('Season'))[1]
# it include Season and Data of that perticular Season
# Out:
# ('IPL-2009',
#        id    Season            city        date                        team1  \
#  148  149  IPL-2009       Centurion  07-05-2009          Chennai Super Kings
#  149  150  IPL-2009     East London  08-05-2009               Mumbai Indians
#  150  151  IPL-2009       Kimberley  09-05-2009              Deccan Chargers
#  151  152  IPL-2009       Kimberley  09-05-2009             Rajasthan Royals
#  152  153  IPL-2009  Port Elizabeth  10-05-2009               Mumbai Indians
#  153  154  IPL-2009    Johannesburg  10-05-2009        Kolkata Knight Riders
#  154  155  IPL-2009       Kimberley  11-05-2009              Deccan Chargers
#  155  156  IPL-2009       Centurion  12-05-2009        Kolkata Knight Riders
#  157  158  IPL-2009          Durban  13-05-2009             Delhi Daredevils
#  158  159  IPL-2009          Durban  14-05-2009          Chennai Super Kings
#  159  160  IPL-2009          Durban  14-05-2009             Rajasthan Royals
# ...

# %%
list(df.groupby('Season'))[4]
# it include Season and Data of that perticular Season
# Out:
# ('IPL-2012',
#        id    Season        city        date                        team1  \
#  366  367  IPL-2012   Bangalore  14-05-2012  Royal Challengers Bangalore
#  365  366  IPL-2012  Chandigarh  13-05-2012              Deccan Chargers
#  364  365  IPL-2012      Jaipur  13-05-2012             Rajasthan Royals
#  363  364  IPL-2012     Chennai  12-05-2012             Delhi Daredevils
#  362  363  IPL-2012     Kolkata  12-05-2012               Mumbai Indians
#  ..   ...       ...         ...         ...                          ...
#  310  311  IPL-2012      Jaipur  06-04-2012             Rajasthan Royals
#  309  310  IPL-2012      Mumbai  06-04-2012                Pune Warriors
#  308  309  IPL-2012     Kolkata  05-04-2012        Kolkata Knight Riders
#  307  308  IPL-2012     Chennai  04-04-2012          Chennai Super Kings
#  313  314  IPL-2012      Jaipur  08-04-2012             Rajasthan Royals
#
#                       team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# # Fetch data from Season 2019

# %%
#using groupby
ipl_19 = df.groupby('Season').get_group('IPL-2019')
ipl_19.head(2)
# Out:
#         id    Season     city        date                team1  \
# 736  11332  IPL-2019  Chennai  23-04-2019  Sunrisers Hyderabad
# 739  11335  IPL-2019  Chennai  26-04-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 736  Chennai Super Kings  Chennai Super Kings         field  normal
# 739  Chennai Super Kings  Chennai Super Kings         field  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 736           0  Chennai Super Kings            0               6
# 739           0       Mumbai Indians           46               0
#
#     player_of_match                      venue      umpire1         umpire2  \
# 736       SR Watson  M. A. Chidambaram Stadium  Nigel Llong  Anil Chaudhary
# 739       RG Sharma  M. A. Chidambaram Stadium  Nigel Llong  Anil Chaudhary
#
#              umpire3
# 736  Vineet Kulkarni
# 739  Vineet Kulkarni

# %%
# How many Matches played
ipl_19.shape[0]
# Out:
# 60

# %%
# who was winner of final match
# final match means last row
ipl_19.tail(1)
# Out:
#         id    Season       city        date           team1  \
# 755  11415  IPL-2019  Hyderabad  12-05-2019  Mumbai Indians
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# 755  Chennai Super Kings  Mumbai Indians           bat  normal           0
#
#              winner  win_by_runs  win_by_wickets player_of_match  \
# 755  Mumbai Indians            1               0       JJ Bumrah
#
#                                   venue      umpire1    umpire2      umpire3
# 755  Rajiv Gandhi Intl. Cricket Stadium  Nitin Menon  Ian Gould  Nigel Llong

# %%
ipl_19.tail(1)['winner']
# Out:
# 755    Mumbai Indians
# Name: winner, dtype: object

# %%
# where last match played and player of the match?
final= ipl_19.tail(1)
final[['venue','player_of_match']]
# Out:
#                                   venue player_of_match
# 755  Rajiv Gandhi Intl. Cricket Stadium       JJ Bumrah

# %%
# where last match played and player of the match and winner of match?
final= ipl_19.tail(1)
final[['venue','player_of_match','winner']]
# Out:
#                                   venue player_of_match          winner
# 755  Rajiv Gandhi Intl. Cricket Stadium       JJ Bumrah  Mumbai Indians

# %% [markdown]
# # groupby on Season and City

# %%
df.groupby(['Season','city'])

# %%
#typecasting
list(df.groupby(['Season','city']))
# Out:
# [(('IPL-2008', 'Bangalore'),
#         id    Season       city        date                        team1  \
#   73    74  IPL-2008  Bangalore  28-04-2008          Chennai Super Kings
#   83    84  IPL-2008  Bangalore  05-05-2008  Royal Challengers Bangalore
#   69    70  IPL-2008  Bangalore  26-04-2008  Royal Challengers Bangalore
#   59    60  IPL-2008  Bangalore  18-04-2008        Kolkata Knight Riders
#   110  111  IPL-2008  Bangalore  03-05-2008  Royal Challengers Bangalore
#   103  104  IPL-2008  Bangalore  19-05-2008  Royal Challengers Bangalore
#   89    90  IPL-2008  Bangalore  28-05-2008  Royal Challengers Bangalore
#
#                              team2                  toss_winner toss_decision  \
#   73   Royal Challengers Bangalore          Chennai Super Kings           bat
#   83               Kings XI Punjab              Kings XI Punjab         field
#   69              Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
# find out IPL -2019 and place Mumbai
df.groupby(['Season','city']).get_group(('IPL-2019','Mumbai'))
# Out:
#         id    Season    city        date                        team1  \
# 746  11342  IPL-2019  Mumbai  02-05-2019               Mumbai Indians
# 751  11347  IPL-2019  Mumbai  05-05-2019        Kolkata Knight Riders
# 726  11322  IPL-2019  Mumbai  15-04-2019  Royal Challengers Bangalore
# 710  11151  IPL-2019  Mumbai  03-04-2019               Mumbai Indians
# 698  11139  IPL-2019  Mumbai  24-03-2019               Delhi Capitals
# 719  11315  IPL-2019  Mumbai  10-04-2019              Kings XI Punjab
# 722  11318  IPL-2019  Mumbai  13-04-2019               Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 746  Sunrisers Hyderabad       Mumbai Indians           bat     tie
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 726       Mumbai Indians       Mumbai Indians         field  normal
# 710  Chennai Super Kings  Chennai Super Kings         field  normal
# ...

# %%
df.city.unique()
# Out:
# array(['Mumbai', 'Jaipur', 'Chandigarh', 'Hyderabad', 'Chennai', 'Delhi',
#        'Kolkata', 'Bangalore', 'Centurion', 'East London', 'Kimberley',
#        'Port Elizabeth', 'Johannesburg', 'Durban', 'Bloemfontein',
#        'Cape Town', 'Ahmedabad', 'Cuttack', 'Dharamsala', 'Nagpur',
#        'Kochi', 'Indore', 'Pune', 'Visakhapatnam', 'Raipur', 'Ranchi',
#        nan, 'Abu Dhabi', 'Sharjah', 'Rajkot', 'Kanpur', 'Bengaluru',
#        'Mohali'], dtype=object)

# %%
# fetch data of MI played matches at Wankhede
mi_win = df.groupby(['team1','venue']).get_group(('Mumbai Indians','Wankhede Stadium'))
mi_win[:2]
# Out:
#       id    Season    city        date           team1  \
# 62    63  IPL-2008  Mumbai  20-04-2008  Mumbai Indians
# 246  247  IPL-2011  Mumbai  15-04-2011  Mumbai Indians
#
#                            team2           toss_winner toss_decision  result  \
# 62   Royal Challengers Bangalore        Mumbai Indians           bat  normal
# 246         Kochi Tuskers Kerala  Kochi Tuskers Kerala         field  normal
#
#      dl_applied                       winner  win_by_runs  win_by_wickets  \
# 62            0  Royal Challengers Bangalore            0               5
# 246           0         Kochi Tuskers Kerala            0               8
#
#     player_of_match             venue      umpire1     umpire2 umpire3
# 62       MV Boucher  Wankhede Stadium     SJ Davis   DJ Harper     NaN
# 246     BB McCullum  Wankhede Stadium  BR Doctrove  PR Reiffel     NaN

# %%
#save above csv file for further use
mi_wan.to_excel('MI_wankhede.xlsx',index=False)

# %% [markdown]
# # Fetch the record of first match played in each season

# %%
df.groupby('Season').first()
# Out:
#              id        city        date                        team1  \
# Season
# IPL-2008    117      Mumbai  01-06-2008          Chennai Super Kings
# IPL-2009    149   Centurion  07-05-2009          Chennai Super Kings
# IPL-2010    178     Kolkata  14-03-2010  Royal Challengers Bangalore
# IPL-2011    247      Mumbai  15-04-2011               Mumbai Indians
# IPL-2012    367   Bangalore  14-05-2012  Royal Challengers Bangalore
# IPL-2013    409  Chandigarh  21-04-2013                Pune Warriors
# IPL-2014    486     Cuttack  07-05-2014              Kings XI Punjab
# IPL-2015    518     Kolkata  08-04-2015               Mumbai Indians
# IPL-2016    579  Chandigarh  11-04-2016              Kings XI Punjab
# IPL-2017      1   Hyderabad  05-04-2017          Sunrisers Hyderabad
# IPL-2018   7934     Kolkata  09-05-2018               Mumbai Indians
# IPL-2019  11332     Chennai  23-04-2019          Sunrisers Hyderabad
#
# ...

# %% [markdown]
# # Fetch the record of final match played in each season

# %%
df.groupby('Season').last()
# Out:
#              id       city        date                  team1  \
# Season
# IPL-2008    113     Jaipur  26-05-2008         Mumbai Indians
# IPL-2009    120  Cape Town  19-04-2009        Kings XI Punjab
# IPL-2010    179    Chennai  14-03-2010        Deccan Chargers
# IPL-2011    241     Jaipur  12-04-2011       Delhi Daredevils
# IPL-2012    314     Jaipur  08-04-2012       Rajasthan Royals
# IPL-2013    385      Delhi  06-04-2013       Rajasthan Royals
# IPL-2014    484     Mumbai  06-05-2014         Mumbai Indians
# IPL-2015    576    Kolkata  24-05-2015         Mumbai Indians
# IPL-2016    577     Mumbai  09-04-2016         Mumbai Indians
# IPL-2017     40    Kolkata  03-05-2017  Kolkata Knight Riders
# IPL-2018   7916     Mumbai  24-04-2018    Sunrisers Hyderabad
# IPL-2019  11415  Hyderabad  12-05-2019         Mumbai Indians
#
#                                 team2                  toss_winner  \
# Season
# IPL-2008             Rajasthan Royals             Rajasthan Royals
# ...

# %%
# need a Seasonwise summation of win_by_wickets and win_by_runs
out = df.groupby('Season')[['win_by_runs','win_by_wickets']].sum()
out
# Out:
#           win_by_runs  win_by_wickets
# Season
# IPL-2008          705             221
# IPL-2009          764             180
# IPL-2010          976             190
# IPL-2011         1098             265
# IPL-2012          960             241
# IPL-2013         1241             227
# IPL-2014          644             225
# IPL-2015          850             148
# IPL-2016          676             244
# IPL-2017          788             204
# IPL-2018          675             186
# IPL-2019          665             202

# %%
# need a Seasonwise summation of win_by_wickets and win_by_runs
out = df.groupby('Season')[['win_by_runs','win_by_wickets']].sum()
out.style.background_gradient('CMRmap')
# Out:
# <style type="text/css">
# #T_aee66_row0_col0 {
#   background-color: #1f1f68;
#   color: #f1f1f1;
# }
# #T_aee66_row0_col1 {
#   background-color: #e67f00;
#   color: #f1f1f1;
# }
# #T_aee66_row1_col0 {
#   background-color: #3d26a6;
#   color: #f1f1f1;
# }
# #T_aee66_row1_col1 {
#   background-color: #5c29b3;
#   color: #f1f1f1;
# }
# #T_aee66_row2_col0 {
#   background-color: #f35d15;
#   color: #f1f1f1;
# }
# #T_aee66_row2_col1 {
#   background-color: #8e3189;
#   color: #f1f1f1;
# }
# #T_aee66_row3_col0 {
#   background-color: #e6c322;
#   color: #000000;
# }
# #T_aee66_row3_col1, #T_aee66_row5_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_aee66_row4_col0 {
#   background-color: #f94f1d;
#   color: #f1f1f1;
# }
# #T_aee66_row4_col1 {
#   background-color: #e6cd3f;
#   color: #000000;
# }
# #T_aee66_row5_col1 {
#   background-color: #e6990a;
#   color: #f1f1f1;
# }
# #T_aee66_row6_col0, #T_aee66_row7_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# ...

# %%
#need a Seasonwise mean of win_by_wickets and win_by_runs
out1=df.groupby('Season')[['win_by_runs','win_by_wickets']].mean()
out1.style.background_gradient('CMRmap')
# Out:
# <style type="text/css">
# #T_fa39a_row0_col0 {
#   background-color: #5027bd;
#   color: #f1f1f1;
# }
# #T_fa39a_row0_col1 {
#   background-color: #e6d95f;
#   color: #000000;
# }
# #T_fa39a_row1_col0, #T_fa39a_row4_col1 {
#   background-color: #ed3e36;
#   color: #f1f1f1;
# }
# #T_fa39a_row1_col1 {
#   background-color: #ba3762;
#   color: #f1f1f1;
# }
# #T_fa39a_row2_col0 {
#   background-color: #fdfdf7;
#   color: #000000;
# }
# #T_fa39a_row2_col1 {
#   background-color: #c1385d;
#   color: #f1f1f1;
# }
# #T_fa39a_row3_col0 {
#   background-color: #e6c62c;
#   color: #000000;
# }
# #T_fa39a_row3_col1 {
#   background-color: #e6b114;
#   color: #000000;
# }
# #T_fa39a_row4_col0 {
#   background-color: #ad366e;
#   color: #f1f1f1;
# }
# #T_fa39a_row5_col0, #T_fa39a_row8_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_fa39a_row5_col1 {
#   background-color: #6f2ca3;
#   color: #f1f1f1;
# }
# #T_fa39a_row6_col0, #T_fa39a_row7_col1 {
#   background-color: #000000;
# ...

# %%
#need a Seasonwise mean of win_by_wickets and win_by_runs
df.groupby('Season')[['win_by_runs','win_by_wickets']].mean()
# Out:
#           win_by_runs  win_by_wickets
# Season
# IPL-2008    12.155172        3.810345
# IPL-2009    13.403509        3.157895
# IPL-2010    16.266667        3.166667
# IPL-2011    15.041096        3.630137
# IPL-2012    12.972973        3.256757
# IPL-2013    16.328947        2.986842
# IPL-2014    10.733333        3.750000
# IPL-2015    14.406780        2.508475
# IPL-2016    11.266667        4.066667
# IPL-2017    13.355932        3.457627
# IPL-2018    11.250000        3.100000
# IPL-2019    11.083333        3.366667
