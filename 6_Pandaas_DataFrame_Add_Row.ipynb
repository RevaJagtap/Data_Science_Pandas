# %% [markdown]
# # Manipulation of DataFrame: How to add rows

# %%
import pandas as pd

# %%
# List of Tuples
students = [ ('jack', 34, 'Sydeny' , 'Australia') ,
             ('Riti', 30, 'Delhi' , 'India' ) ,
             ('Vikas', 31, 'Mumbai' , 'India' ) ,
             ('Neelu', 32, 'Bangalore' , 'India' ) ,
             ('John', 16, 'New York' , 'US') ,
             ('Mike', 17, 'las vegas' , 'US')  ]

# %%
students
# Out:
# [('jack', 34, 'Sydeny', 'Australia'),
#  ('Riti', 30, 'Delhi', 'India'),
#  ('Vikas', 31, 'Mumbai', 'India'),
#  ('Neelu', 32, 'Bangalore', 'India'),
#  ('John', 16, 'New York', 'US'),
#  ('Mike', 17, 'las vegas', 'US')]

# %%
#Create a DataFrame object
df = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['a', 'b', 'c' , 'd' , 'e' , 'f']) 
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %% [markdown]
# # Using dataframe.append() and Dictionary

# %%
df.head(2)
# Out:
#    Name  Age    City    Country
# a  jack   34  Sydeny  Australia
# b  Riti   30   Delhi      India

# %%
# Pass the row elements as key value pairs to append() function 
modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} )
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\948662361.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} )
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1208\948662361.py in <module>
#       1 # Pass the row elements as key value pairs to append() function
# ----> 2 modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} )
#       3 modDfObj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9046         )
#    9047
# -> 9048         return self._append(other, ignore_index, verify_integrity, sort)
#    9049
#    9050     def _append(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9059             if isinstance(other, dict):
#    9060                 if not ignore_index:
# -> 9061                     raise TypeError("Can only append a dict if ignore_index=True")
#    9062                 other = Series(other)
#    9063             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} , ignore_index=True)##modDFObj=modified object
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\1305470020.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} , ignore_index=True)##modDFObj=modified object
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Sunil   22        NaN        NaN

# %%
modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22,'pincode':123456} , ignore_index=True)
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\1972185284.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22,'pincode':123456} , ignore_index=True)
#     Name  Age       City    Country   pincode
# 0   jack   34     Sydeny  Australia       NaN
# 1   Riti   30      Delhi      India       NaN
# 2  Vikas   31     Mumbai      India       NaN
# 3  Neelu   32  Bangalore      India       NaN
# 4   John   16   New York         US       NaN
# 5   Mike   17  las vegas         US       NaN
# 6  Sunil   22        NaN        NaN  123456.0

# %% [markdown]
# # dataframe.append() and Series

# %%
s = pd.Series(['Raju', 21, 'Bangalore', 'India'],index=['Name','Age','City','Country'] )
s
# Out:
# Name            Raju
# Age               21
# City       Bangalore
# Country        India
# dtype: object

# %%
# Pass a series in append() to append a row in dataframe  ---#df.columns
modDfObj = df.append(s,ignore_index=True)
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\1125096512.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append(s,ignore_index=True)
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6   Raju   21  Bangalore      India

# %%
r = pd.Series(['Rohit',23,'Paris','US'])
r
# Out:
# 0    Rohit
# 1       23
# 2    Paris
# 3       US
# dtype: object

# %%
modDfObj = df.append(r,ignore_index=True)
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\1616651017.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append(r,ignore_index=True)
#     Name   Age       City    Country      0     1      2    3
# 0   jack  34.0     Sydeny  Australia    NaN   NaN    NaN  NaN
# 1   Riti  30.0      Delhi      India    NaN   NaN    NaN  NaN
# 2  Vikas  31.0     Mumbai      India    NaN   NaN    NaN  NaN
# 3  Neelu  32.0  Bangalore      India    NaN   NaN    NaN  NaN
# 4   John  16.0   New York         US    NaN   NaN    NaN  NaN
# 5   Mike  17.0  las vegas         US    NaN   NaN    NaN  NaN
# 6    NaN   NaN        NaN        NaN  Rohit  23.0  Paris   US

# %%
m=pd.Series(['Reva',28,'Mumbai','India'])
m
# Out:
# 0      Reva
# 1        28
# 2    Mumbai
# 3     India
# dtype: object

# %%
modDfObj = df.append(m,ignore_index=True)
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\480972675.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append(m,ignore_index=True)
#     Name   Age       City    Country     0     1       2      3
# 0   jack  34.0     Sydeny  Australia   NaN   NaN     NaN    NaN
# 1   Riti  30.0      Delhi      India   NaN   NaN     NaN    NaN
# 2  Vikas  31.0     Mumbai      India   NaN   NaN     NaN    NaN
# 3  Neelu  32.0  Bangalore      India   NaN   NaN     NaN    NaN
# 4   John  16.0   New York         US   NaN   NaN     NaN    NaN
# 5   Mike  17.0  las vegas         US   NaN   NaN     NaN    NaN
# 6    NaN   NaN        NaN        NaN  Reva  28.0  Mumbai  India

# %%
r = pd.Series(['Rohit',23,'Paris','US'],index=['Name','Age','City','Country'])
r
# Out:
# Name       Rohit
# Age           23
# City       Paris
# Country       US
# dtype: object

# %%
modDfObj = df.append(r,ignore_index=True)
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\1616651017.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append(r,ignore_index=True)
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Rohit   23      Paris         US

# %% [markdown]
# # Add multiple rows

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country'], dtype='object')

# %%
pd.Series(['Raju', 21, 'Bangalore', 'India'],index=df.columns)#['Name']
# Out:
# Name            Raju
# Age               21
# City       Bangalore
# Country        India
# dtype: object

# %%
# List of series  
listOfSeries = [pd.Series(['Raju', 21, 'Bangalore', 'India'], index=df.columns ) ,
                pd.Series(['Sam', 22, 'Tokyo', 'Japan'], index=df.columns ) ,
                pd.Series(['Rocky', 23, 'Las Vegas', 'US'], index=df.columns ) ]
listOfSeries
# Out:
# [Name            Raju
#  Age               21
#  City       Bangalore
#  Country        India
#  dtype: object,
#  Name         Sam
#  Age           22
#  City       Tokyo
#  Country    Japan
#  dtype: object,
#  Name           Rocky
#  Age               23
#  City       Las Vegas
#  Country           US
#  dtype: object]

# %%
# Pass a list of series to the append() to add multiple rows
modDfObj = df.append(listOfSeries)
modDfObj
# here if we check index, then its not in proper order
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\2888939371.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append(listOfSeries)
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US
# 0   Raju   21  Bangalore      India
# 1    Sam   22      Tokyo      Japan
# 2  Rocky   23  Las Vegas         US

# %%
# use ignore_index =True to scale index
modDfObj = df.append(listOfSeries , ignore_index=True)
modDfObj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\332480763.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfObj = df.append(listOfSeries , ignore_index=True)
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6   Raju   21  Bangalore      India
# 7    Sam   22      Tokyo      Japan
# 8  Rocky   23  Las Vegas         US

# %% [markdown]
# # Add a row from one dataframe to other datafram

# %%
# List of Tuples
students = [ ('Rahul', 22, 'Sydeny' , 'Australia') ,
             ('Parul', 23, 'Pune' , 'India')  ]
#Create a DataFrame object
df2 = pd.DataFrame(students, columns = df.columns, index=['a', 'b']) 
df2
# Out:
#     Name  Age    City    Country
# a  Rahul   22  Sydeny  Australia
# b  Parul   23    Pune      India

# %%
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %%
modDfobj = df.append(df2, ignore_index=True)
modDfobj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\1256185897.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfobj = df.append(df2, ignore_index=True)
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Rahul   22     Sydeny  Australia
# 7  Parul   23       Pune      India

# %%
df2
# Out:
#     Name  Age    City    Country
# a  Rahul   22  Sydeny  Australia
# b  Parul   23    Pune      India

# %%
# label based selection
n=df2.loc['b'] #[rows,columns]
n
# Out:
# Name       Parul
# Age           23
# City        Pune
# Country    India
# Name: b, dtype: object

# %%
# add row at index b from dataframe df2 to dataframe dfObj
modDfobj = df.append(n, ignore_index=True)
modDfobj
# Out:
# C:\Users\YugandharJagtap\AppData\Local\Temp\ipykernel_1208\3691142926.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modDfobj = df.append(n, ignore_index=True)
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Parul   23       Pune      India

# %% [markdown]
# # without append how to add rows

# %%
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %%
# Add a new row at index k with values provided in list
df.loc['k'] = ['Smriti', 26, 'Bangalore', 'India']
df
# Out:
#      Name  Age       City    Country
# a    jack   34     Sydeny  Australia
# b    Riti   30      Delhi      India
# c   Vikas   31     Mumbai      India
# d   Neelu   32  Bangalore      India
# e    John   16   New York         US
# f    Mike   17  las vegas         US
# k  Smriti   26  Bangalore      India

# %%
#if index is already present, in df
#if we want to add new data,then it will overwrite data
df.loc['e'] = ['Pravin', 26, 'Pune', 'India']
df
# Out:
#      Name  Age       City    Country
# a    jack   34     Sydeny  Australia
# b    Riti   30      Delhi      India
# c   Vikas   31     Mumbai      India
# d   Neelu   32  Bangalore      India
# e  Pravin   26       Pune      India
# f    Mike   17  las vegas         US
# k  Smriti   26  Bangalore      India

# %%
df.loc['e']
# Out:
# Name       Pravin
# Age            26
# City         Pune
# Country     India
# Name: e, dtype: object

# %% [markdown]
# - I want to add entries/rows in between the present data frame
# - NOTE: I dont want to overwrite data

# %%
df3 = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=[1,2,3,4,5,6]) 
df3
# Out:
#     Name  Age       City    Country
# 1   jack   34     Sydeny  Australia
# 2   Riti   30      Delhi      India
# 3  Vikas   31     Mumbai      India
# 4  Neelu   32  Bangalore      India
# 5   John   16   New York         US
# 6   Mike   17  las vegas         US

# %%
df3.loc[3.5]=['Pooja','30','Pune','India']

# %%
df3.sort_index().reset_index(drop=True)
# Out:
#     Name Age       City    Country
# 0   jack  34     Sydeny  Australia
# 1   Riti  30      Delhi      India
# 2  Vikas  31     Mumbai      India
# 3  Pooja  30       Pune      India
# 4  Neelu  32  Bangalore      India
# 5   John  16   New York         US
# 6   Mike  17  las vegas         US

# %%
df
# Out:
#    index   Name Age       City    Country
# 0    1.0   jack  34     Sydeny  Australia
# 1    2.0   Riti  30      Delhi      India
# 2    3.0  Vikas  31     Mumbai      India
# 3    3.5   Reva  29       Pune      India
# 4    4.0  Neelu  32  Bangalore      India
# 5    5.0   John  16   New York         US
# 6    6.0   Mike  17  las vegas         US

# %%
df.drop(['index'],axis=1)
# Out:
#     Name Age       City    Country
# 0   jack  34     Sydeny  Australia
# 1   Riti  30      Delhi      India
# 2  Vikas  31     Mumbai      India
# 3   Reva  29       Pune      India
# 4  Neelu  32  Bangalore      India
# 5   John  16   New York         US
# 6   Mike  17  las vegas         US

# %%
df4 = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['A','C','V','D','R','M']) 
df4
# Out:
#     Name  Age       City    Country
# A   jack   34     Sydeny  Australia
# C   Riti   30      Delhi      India
# V  Vikas   31     Mumbai      India
# D  Neelu   32  Bangalore      India
# R   John   16   New York         US
# M   Mike   17  las vegas         US

# %%
df4.loc['E']=['Dyana','3','Pune','India']

# %%
df4.sort_index().reset_index(drop=True)
# Out:
#     Name Age       City    Country
# 0   jack  34     Sydeny  Australia
# 1   Riti  30      Delhi      India
# 2  Neelu  32  Bangalore      India
# 3  Dyana   3       Pune      India
# 4   Mike  17  las vegas         US
# 5   John  16   New York         US
# 6  Vikas  31     Mumbai      India

# %%
df5 = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['A','C','V','D','R','M']) 
df5
# Out:
#     Name  Age       City    Country
# A   jack   34     Sydeny  Australia
# C   Riti   30      Delhi      India
# V  Vikas   31     Mumbai      India
# D  Neelu   32  Bangalore      India
# R   John   16   New York         US
# M   Mike   17  las vegas         US

# %%
df5.loc['H']=['Gatha','3','Kop','India']

# %%
df5.sort_index()
# Out:
#     Name Age       City    Country
# A   jack  34     Sydeny  Australia
# C   Riti  30      Delhi      India
# D  Neelu  32  Bangalore      India
# H  Gatha   3        Kop      India
# M   Mike  17  las vegas         US
# R   John  16   New York         US
# V  Vikas  31     Mumbai      India

# %%
df5
# Out:
#     Name Age       City    Country
# A   jack  34     Sydeny  Australia
# C   Riti  30      Delhi      India
# V  Vikas  31     Mumbai      India
# D  Neelu  32  Bangalore      India
# R   John  16   New York         US
# M   Mike  17  las vegas         US
# H  Gatha   3        Kop      India

# %%
df6 = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['A','C','V','D','R','M']) 
df6
# Out:
#     Name  Age       City    Country
# A   jack   34     Sydeny  Australia
# C   Riti   30      Delhi      India
# V  Vikas   31     Mumbai      India
# D  Neelu   32  Bangalore      India
# R   John   16   New York         US
# M   Mike   17  las vegas         US

# %%
df6.loc[3.5]=['Reva','28','Karad','India']

# %%
df6.sort_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1208\2914907262.py in <module>
# ----> 1 df6.sort_index()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    6454         d  4
#    6455         """
# -> 6456         return super().sort_index(
#    6457             axis,
#    6458             level,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    4683         target = self._get_axis(axis)
#    4684
# -> 4685         indexer = get_indexer_indexer(
#    4686             target, level, ascending, kind, na_position, sort_remaining, key
#    4687         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\sorting.py in get_indexer_indexer(target, level, ascending, kind, na_position, sort_remaining, key)
#      92             return None
#      93
# ---> 94         indexer = nargsort(
#      95             target, kind=kind, ascending=ascending, na_position=na_position
#      96         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position, key, mask)
#     415         non_nans = non_nans[::-1]
#     416         non_nan_idx = non_nan_idx[::-1]
# --> 417     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     418     if not ascending:
#     419         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
df6.reset_index()
# Out:
#   index   Name Age       City    Country
# 0     A   jack  34     Sydeny  Australia
# 1     C   Riti  30      Delhi      India
# 2     V  Vikas  31     Mumbai      India
# 3     D  Neelu  32  Bangalore      India
# 4     R   John  16   New York         US
# 5     M   Mike  17  las vegas         US
# 6   3.5   Reva  28      Karad      India

# %%
df6.reset_index(drop=True)
# Out:
#     Name Age       City    Country
# 0   jack  34     Sydeny  Australia
# 1   Riti  30      Delhi      India
# 2  Vikas  31     Mumbai      India
# 3  Neelu  32  Bangalore      India
# 4   John  16   New York         US
# 5   Mike  17  las vegas         US
# 6   Reva  28      Karad      India
